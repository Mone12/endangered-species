# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\monee\OneDrive\Documents\species_info.csv")
df['conservation_status'] = df['conservation_status'].fillna('Stable')
df
# Cleaned Data
# Out:
#             category                scientific_name  \
# 0             Mammal  Clethrionomys gapperi gapperi
# 1             Mammal                      Bos bison
# 2             Mammal                     Bos taurus
# 3             Mammal                     Ovis aries
# 4             Mammal                 Cervus elaphus
# ...              ...                            ...
# 5819  Vascular Plant               Solanum parishii
# 5820  Vascular Plant                  Solanum xanti
# 5821  Vascular Plant         Parthenocissus vitacea
# 5822  Vascular Plant              Vitis californica
# 5823  Vascular Plant            Tribulus terrestris
#
#                                            common_names conservation_status
# 0                              Gapper's Red-Backed Vole              Stable
# 1                                 American Bison, Bison              Stable
# 2     Aurochs, Aurochs, Domestic Cattle (Feral), Dom...              Stable
# 3     Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)              Stable
# 4                                         Wapiti Or Elk              Stable
# ...                                                 ...                 ...
# 5819                                Parish's Nightshade              Stable
# 5820            Chaparral Nightshade, Purple Nightshade              Stable
# 5821        Thicket Creeper, Virginia Creeper, Woodbine              Stable
# 5822            California Grape, California Wild Grape              Stable
# 5823  Bullhead, Caltrop, Goathead, Mexican Sandbur, ...              Stable
#
# [5824 rows x 4 columns]

# %%
status_df =df.groupby(['conservation_status'], as_index=False)['category'].count()
status_df
# Counting the status of each species by category
# Out:
#   conservation_status  category
# 0          Endangered        16
# 1         In Recovery         4
# 2  Species of Concern       161
# 3              Stable      5633
# 4          Threatened        10

# %%
status_df.plot(x='conservation_status', y='category')
plt.legend(loc="best")
plt.title('Species Status')
plt.xlabel("Status")
plt.ylabel("Species")
plt.grid()
plt.show()

# Chart shows that the majority of overall species are stable

# %%
named_species = df.groupby(['category'], as_index=False)['scientific_name'].count()
named_species
#Counting how many recorded species are there in each category
# Out:
#             category  scientific_name
# 0          Amphibian               80
# 1               Bird              521
# 2               Fish              127
# 3             Mammal              214
# 4  Nonvascular Plant              333
# 5            Reptile               79
# 6     Vascular Plant             4470

# %%
vas_plants= df.loc[df['category']=='Vascular Plant']
vas_plants
# Out:
#             category                      scientific_name  \
# 574   Vascular Plant                       Acorus calamus
# 575   Vascular Plant                   Alisma subcordatum
# 576   Vascular Plant                 Sagittaria australis
# 577   Vascular Plant  Sagittaria latifolia var. pubescens
# 578   Vascular Plant                  Arisaema dracontium
# ...              ...                                  ...
# 5819  Vascular Plant                     Solanum parishii
# 5820  Vascular Plant                        Solanum xanti
# 5821  Vascular Plant               Parthenocissus vitacea
# 5822  Vascular Plant                    Vitis californica
# 5823  Vascular Plant                  Tribulus terrestris
#
#                                            common_names conservation_status
# 574                                           Sweetflag              Stable
# 575                                      Water-Plantain              Stable
# 576                                  Longbeak Arrowhead              Stable
# 577                              Broad-Leaved Arrowhead              Stable
# 578                                        Green Dragon              Stable
# ...                                                 ...                 ...
# 5819                                Parish's Nightshade              Stable
# 5820            Chaparral Nightshade, Purple Nightshade              Stable
# 5821        Thicket Creeper, Virginia Creeper, Woodbine              Stable
# 5822            California Grape, California Wild Grape              Stable
# 5823  Bullhead, Caltrop, Goathead, Mexican Sandbur, ...              Stable
#
# [4470 rows x 4 columns]

# %%
birds_df= df.loc[df['category']=='Bird']
birds_df
# Out:
#      category                scientific_name        common_names  \
# 90       Bird  Vermivora pinus X chrysoptera  Brewster's Warbler
# 91       Bird             Accipiter cooperii       Cooper's Hawk
# 92       Bird             Accipiter gentilis    Northern Goshawk
# 93       Bird             Accipiter striatus  Sharp-Shinned Hawk
# 94       Bird              Aquila chrysaetos        Golden Eagle
# ...       ...                            ...                 ...
# 4571     Bird               Glaucidium gnoma  Northern Pygmy Owl
# 4572     Bird                Otus flammeolus     Flammulated Owl
# 4573     Bird                 Strix nebulosa      Great Gray Owl
# 4574     Bird             Strix occidentalis         Spotted Owl
# 4575     Bird                      Tyto alba            Barn Owl
#
#      conservation_status
# 90                Stable
# 91    Species of Concern
# 92                Stable
# 93    Species of Concern
# 94    Species of Concern
# ...                  ...
# 4571              Stable
# 4572              Stable
# 4573              Stable
# 4574              Stable
# 4575              Stable
#
# [521 rows x 4 columns]

# %%
nonVas_plants= df.loc[df['category']=='Nonvascular Plant']
nonVas_plants
# Out:
#                category                 scientific_name  \
# 2679  Nonvascular Plant                 Andreaea rothii
# 2680  Nonvascular Plant              Andreaea rupestris
# 2681  Nonvascular Plant            Bartramia pomiformis
# 2682  Nonvascular Plant              Philonotis fontana
# 2683  Nonvascular Plant  Philonotis fontana var. pumila
# ...                 ...                             ...
# 3007  Nonvascular Plant             Sphagnum squarrosum
# 3008  Nonvascular Plant            Sphagnum subsecundum
# 3009  Nonvascular Plant             Tetraphis pellucida
# 3010  Nonvascular Plant         Tetrodontium brownianum
# 4445  Nonvascular Plant                      Fontinalis
#
#                    common_names conservation_status
# 2679       Roth's Andreaea Moss              Stable
# 2680              Andreaea Moss              Stable
# 2681             Bartramia Moss              Stable
# 2682            Philonotis Moss              Stable
# 2683            Philonotis Moss              Stable
# ...                         ...                 ...
# 3007                   Sphagnum              Stable
# 3008                   Sphagnum              Stable
# 3009             Tetraphis Moss              Stable
# 3010  Brown's Tetrodontium Moss              Stable
# 4445            Fontinalis Moss              Stable
#
# [333 rows x 4 columns]

# %%
amphib_df= df.loc[df['category']=='Amphibian']
amphib_df

amphib_status = amphib_df.groupby(['conservation_status'], as_index=False)['category'].count()
amphib_status
# Out:
#   conservation_status  category
# 0          Endangered         1
# 1  Species of Concern         4
# 2              Stable        73
# 3          Threatened         2

# %%
reptile_df= df.loc[df['category']=='Reptile']


reptile_status = reptile_df.groupby(['conservation_status'], as_index=False)['category'].count()
reptile_status
# Out:
#   conservation_status  category
# 0  Species of Concern         5
# 1              Stable        74

# %%
fish_df= df.loc[df['category']=='Fish']
fish_df

fish_status = fish_df.groupby(['conservation_status'], as_index=False)['category'].count()
fish_status
# Out:
#   conservation_status  category
# 0          Endangered         3
# 1  Species of Concern         4
# 2              Stable       116
# 3          Threatened         4

# %%
mammals_df= df.loc[df['category']=='Mammal']
mammals_df

mammal_status = mammals_df.groupby(['conservation_status'], as_index=False)['category'].count()
mammal_status

# %%
nonVas_status = nonVas_plants.groupby(['conservation_status'], as_index=False)['category'].count()
nonVas_status
# Out:
#   conservation_status  category
# 0  Species of Concern         5
# 1              Stable       328

# %%
bird_status = birds_df.groupby(['conservation_status'], as_index=False)['category'].count()
bird_status
#BIRD Status
# Out:
#   conservation_status  category
# 0          Endangered         4
# 1         In Recovery         3
# 2  Species of Concern        72
# 3              Stable       442

# %%
vas_status = vas_plants.groupby(['conservation_status'], as_index=False)['category'].count()
vas_status
#VASCULAR PLANT status
# Out:
#   conservation_status  category
# 0          Endangered         1
# 1  Species of Concern        43
# 2              Stable      4424
# 3          Threatened         2

# %%
species = ["Amphibian", "Bird", "Fish", "Mammal","Nonvascular Plant","Reptile", "Vascular Plant"]
number = [80,521,127,214,333,79,4470]

plt.pie(number, labels=species,startangle=100)
plt.show()

#Pie chart and graph shows that the majority of recorded species are Vascular Plants

# %%
observations_df = pd.read_csv(r"C:\Users\monee\OneDrive\Documents\observations.csv")
observations_df.drop_duplicates(subset=['scientific_name'])
observations_df
 
# Data of observations recorded of species at National Parks
# Out:
#                                scientific_name  \
# 0                           Vicia benghalensis
# 1                               Neovison vison
# 2                            Prunus subcordata
# 3                         Abutilon theophrasti
# 4                     Githopsis specularioides
# ...                                        ...
# 23291                     Croton monanthogynus
# 23292                 Otospermophilus beecheyi
# 23293  Heterotheca sessiliflora ssp. echioides
# 23294                     Dicranella rufescens
# 23295                           Cucurbita pepo
#
#                                  park_name  observations
# 0      Great Smoky Mountains National Park            68
# 1      Great Smoky Mountains National Park            77
# 2                   Yosemite National Park           138
# 3                      Bryce National Park            84
# 4      Great Smoky Mountains National Park            85
# ...                                    ...           ...
# 23291               Yosemite National Park           173
# 23292                  Bryce National Park           130
# 23293                  Bryce National Park           140
# 23294               Yosemite National Park           171
# 23295               Yosemite National Park           164
#
# [23296 rows x 3 columns]

# %%
o_df = observations_df.groupby(['park_name'], as_index=False)['scientific_name'].count()
o_df
#Chart of how many species are at each park
# Out:
#                              park_name  scientific_name
# 0                  Bryce National Park             5824
# 1  Great Smoky Mountains National Park             5824
# 2            Yellowstone National Park             5824
# 3               Yosemite National Park             5824

# %%
parks = ["Bryce National Park", "Great Smokey Mountains National Park", "Yellowstone National Park", "Yosemite National Park"]
animals = [5824,5824,5824,5824]

plt.pie(animals, labels=parks, colors=["pink","purple","blue","yellow"],startangle=100)
plt.show()
# Chart shows that species are divided evenly at each park

# %%
total_observ = observations_df['observations'].sum()
total_observ
# Out:
# 3314739

# %%
average_observ = observations_df['observations'].mean()
average_observ
# Out:
# 142.28790350274724
